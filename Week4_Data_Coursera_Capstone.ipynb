# %% [markdown]
# ## Exploring neighborhood - DATA (part 1 of Capstone Project)

# %% [markdown]
# ### Data - sourcing and usage

# %% [markdown]
# To answer main question of the project - i.e. choose best place to start with Robotics club following steps will be performed:

# %% [markdown]
# 1. Geospatial data. We need to divide city into at least districts if not neighborhoods. Geospatial data I only to find for Kyiv was .geojson file that contains polygon coordinates of each district borders. We then need to pick centers of neighborhoods somehow. This might be using borders coordinates or choosing randomly centers within polygons or manual choice of centers within districts
# https://github.com/denysboiko/kyivmap/blob/1ad68c16c2aa1f2bfe5a31fbbc261b722fbf6a0c/static/media/kyiv.34272c8c.geojson

# %% [markdown]
# 2. Main parameters of choice are Primary schools / Rivals / Other courses / Rent level.
# All this can be answered using Foursquare data. As it is can be seen (see example below) request for search_query = 'primary school' in Kyiv, returns only couple primary schools and rest is plenty of various Courses / Language Schools / Coworking etc.
#  1. Using category we might filter only schools and for each Neighborhood record quantity of schools in 2-3 km radius
#  2. Using category we might as well filter rivals (if it is technical education) and other courses for same age group (non-technical education). That quantities would give us rivals and complements.
#  3. To define indirectly higher / lower rent expected, I decided to use following assumption: the more restaurants / cafee / bars is near - the higher rent rate is. So additional parameters for each neighborhood will be expensive (in terms of rent) objects.

# %% [markdown]
# 3. Having collected and munged data on previous step Expert opinion is required for setting level of importance of each parameter. Then we would be able to define the best options.
# Such coefficients might be defined basis humble opinion. However, there is more sophisticated but reliable way to get them. We can use locations of existing Robotics courses / Technical clubs and check their surroundings then using actual data of shares in each group among total venues as importance coefficients.

# %% [markdown]
# Below you can find aforementioned example of "primary schools" request for Kyiv (to be used for defining Schools / Rivals / Complements (non-technical courses) and 200 city venues (to be used for defining share of each type of venues for existing Robotics clubs)

# %%
#importing libraries
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')

# %%
#Let us look at the city as a whole, so get coordinates of Kyiv
address = 'Kyiv, Ukraine'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address,latitude, longitude))
# Out:
# The geograpical coordinate of Kyiv, Ukraine are 50.4500336, 30.5241361.

# %%
results = pd.DataFrame({'Name':['Kyiv'],'Latitude':[latitude],'Longitude':[longitude]})

# %%
results
# Out:
#    Name   Latitude  Longitude
# 0  Kyiv  50.450034  30.524136

# %%
#Credentials. You don't mean to use them, do you ?
CLIENT_ID = 'N2NVGFIVEEPWIDUNHMWCR0Q2HIQI3XYGO03OVZ3CD5JCK2D0' # your Foursquare ID
CLIENT_SECRET = 'HFQRYHNC5BWU3YTFDQLNN0KLDSD2YOLOZEMHY3SCCYTU4WZE' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
radius = 1000
LIMIT = 100
search_query = 'primary school'
# create the API request URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
#url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID,CLIENT_SECRET,VERSION,latitude,longitude,radius,LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=N2NVGFIVEEPWIDUNHMWCR0Q2HIQI3XYGO03OVZ3CD5JCK2D0&client_secret=HFQRYHNC5BWU3YTFDQLNN0KLDSD2YOLOZEMHY3SCCYTU4WZE&ll=50.4500336,30.5241361&v=20180605&query=primary school&radius=1000&limit=100'

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d63ac78ad1789002c8dc86c'},
#  'response': {'venues': [{'id': '4f5f8dffe4b01a2cc85e0ead',
#     'name': 'New York Language School',
#     'location': {'address': 'вул. Пушкінська, 12а',
#      'lat': 50.44622426192626,
#      'lng': 30.51844793192073,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44622426192626,
#        'lng': 30.51844793192073}],
#      'distance': 585,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Пушкінська, 12а', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '57ee10ba498eeb97eaf896c2',
#     'name': 'Progress English School',
#     'location': {'address': 'Вулиця Хрещатик, 7/11',
#      'crossStreet': 'Інститутська',
#      'lat': 50.45074,
#      'lng': 30.526152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.45074,
#        'lng': 30.526152}],
#      'distance': 163,
#      'postalCode': '01001',
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Вулиця Хрещатик, 7/11 (Інститутська)',
#       'Київ, 01001',
#       'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '5b0e2dc4ccad6b002cd649c1',
#     'name': 'Progress English School',
#     'location': {'address': 'Patorzhinskogo str, 6',
#      'lat': 50.449112276034086,
#      'lng': 30.517014256580325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.449112276034086,
#        'lng': 30.517014256580325}],
#      'distance': 515,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Patorzhinskogo str, 6', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '52440df011d21bfeca49f4a2',
#     'name': 'Boyko Beauty Salon & School',
#     'location': {'address': 'вул. Богдана Хмельницького, 10А',
#      'crossStreet': 'Ул. Хрещатик',
#      'lat': 50.446203996207245,
#      'lng': 30.51744569102109,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.446203996207245,
#        'lng': 30.51744569102109}],
#      'distance': 637,
#      'postalCode': '01021',
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Богдана Хмельницького, 10А (Ул. Хрещатик)',
#       'Київ, 01021',
#       'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '57864eb9498e51f9587ee943',
#     'name': 'Boyko Beauty Salon & School',
#     'location': {'address': 'вул. Інститутська, 2а',
#      'crossStreet': 'вул. Хрещатик',
#      'lat': 50.44929356795189,
#      'lng': 30.525929958528252,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44929356795189,
#        'lng': 30.525929958528252}],
#      'distance': 151,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Інститутська, 2а (вул. Хрещатик)',
#       'Київ',
#       'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '53776eb0498e54f5e2d65a02',
#     'name': 'Школа современного массажа "Инкорте" / Inсorte, School of Contemporary massage (Школа сучасного масажу "Інкорте")',
#     'location': {'address': 'Мала Житомирська, 20 д',
#      'lat': 50.453874696693106,
#      'lng': 30.520603136268228,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.453874696693106,
#        'lng': 30.520603136268228}],
#      'distance': 495,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Мала Житомирська, 20 д', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a46',
#       'name': 'Private School',
#       'pluralName': 'Private Schools',
#       'shortName': 'Private School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '5c2dfd3f41b6c90025f66e8c',
#     'name': 'ALOHA Language School',
#     'location': {'address': '13 Михайловская улица',
#      'lat': 50.453234,
#      'lng': 30.521322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.453234,
#        'lng': 30.521322}],
#      'distance': 408,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['13 Михайловская улица', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '52a094ff11d2fa5cc42dbdcb',
#     'name': 'Free Art School',
#     'location': {'lat': 50.450908,
#      'lng': 30.525239,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.450908,
#        'lng': 30.525239}],
#      'distance': 124,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4fffbde2e4b0b435844e993b',
#     'name': "Denis' School",
#     'location': {'address': 'вул. Велика Васильківська, 13/1',
#      'lat': 50.44052866652516,
#      'lng': 30.51955607864686,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44052866652516,
#        'lng': 30.51955607864686}],
#      'distance': 1106,
#      'postalCode': '01004',
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Велика Васильківська, 13/1',
#       'Київ, 01004',
#       'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '5230799211d2a4689ad5afba',
#     'name': 'Washington language school',
#     'location': {'lat': 50.44659752443567,
#      'lng': 30.515382903118248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44659752443567,
#        'lng': 30.515382903118248}],
#      'distance': 728,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4f5f1a8ee4b0e5574b7da547',
#     'name': 'Greenwich School',
#     'location': {'address': 'вул. Прорізна, 18/1-г, оф. 3',
#      'crossStreet': 'вул. Паторжинського',
#      'lat': 50.448989777231915,
#      'lng': 30.516563611163768,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.448989777231915,
#        'lng': 30.516563611163768}],
#      'distance': 549,
#      'postalCode': '01034',
#      'cc': 'UA',
#      'city': 'Киев',
#      'state': 'Київська обл.',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Прорізна, 18/1-г, оф. 3 (вул. Паторжинського)',
#       'Киев, 01034',
#       'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '59557745db1d8148fea09c9e',
#     'name': 'PDG School',
#     'location': {'address': 'Львівська пл., 8',
#      'crossStreet': 'вул. Велика Житомирська',
#      'lat': 50.45491,
#      'lng': 30.505852,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.45491,
#        'lng': 30.505852}],
#      'distance': 1405,
#      'cc': 'UA',
#      'neighborhood': 'Старый город',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Львівська пл., 8 (вул. Велика Житомирська)',
#       'Київ',
#       'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4f75aa45e4b02ca6e47b3cf6',
#     'name': 'Valerys School Of English',
#     'location': {'lat': 50.452496744348,
#      'lng': 30.522402192119106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.452496744348,
#        'lng': 30.522402192119106}],
#      'distance': 300,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d19b941735',
#       'name': 'College Science Building',
#       'pluralName': 'College Science Buildings',
#       'shortName': 'Science',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_science_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '506dc3d7e4b066d6fd293648',
#     'name': 'Arthur Murray Dance School',
#     'location': {'address': 'Luteranskaya 10a',
#      'lat': 50.444943354050004,
#      'lng': 30.52372114384642,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.444943354050004,
#        'lng': 30.52372114384642}],
#      'distance': 567,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Luteranskaya 10a', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d134941735',
#       'name': 'Dance Studio',
#       'pluralName': 'Dance Studios',
#       'shortName': 'Dance Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4eb43954722e578a4ee92297',
#     'name': 'G-school',
#     'location': {'address': 'Ул Богдана Хмельницкого 24',
#      'lat': 50.44665427918771,
#      'lng': 30.516405826182766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44665427918771,
#        'lng': 30.516405826182766}],
#      'distance': 664,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Ул Богдана Хмельницкого 24', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d1e9931735',
#       'name': 'Rock Club',
#       'pluralName': 'Rock Clubs',
#       'shortName': 'Rock Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_rockclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4ed47cebb8f70c8aa6c2f91b',
#     'name': 'Школа №25',
#     'location': {'address': 'вул. Володимирська, 1',
#      'lat': 50.45767702956349,
#      'lng': 30.518649657195954,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.45767702956349,
#        'lng': 30.518649657195954}],
#      'distance': 935,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Володимирська, 1', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '5addd62635d3fc1c9d1a6d24',
#     'name': 'Ukrainian Wine & Spirit School',
#     'location': {'address': 'Малая Житомирская 20б',
#      'lat': 50.453911,
#      'lng': 30.520091,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.453911,
#        'lng': 30.520091}],
#      'distance': 518,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Малая Житомирская 20б', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a46',
#       'name': 'Private School',
#       'pluralName': 'Private Schools',
#       'shortName': 'Private School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '525f99c511d2c1ac6e2032f2',
#     'name': "D'elite English School",
#     'location': {'address': 'Рогнединская 3',
#      'lat': 50.44216152279048,
#      'lng': 30.519549880326018,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44216152279048,
#        'lng': 30.519549880326018}],
#      'distance': 934,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Рогнединская 3', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '55c11215498e9644c88452d7',
#     'name': 'ALOHA Language School',
#     'location': {'address': 'Ул. Пушкинская 33 а/ 3',
#      'lat': 50.44170132253408,
#      'lng': 30.516923607869394,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44170132253408,
#        'lng': 30.516923607869394}],
#      'distance': 1059,
#      'postalCode': '01034',
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Ул. Пушкинская 33 а/ 3', 'Київ, 01034', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '136412953'},
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '55f58865498e888ef82f277f',
#     'name': 'CANactions School for urban studies',
#     'location': {'address': 'Ул. Михайловская 22б',
#      'lat': 50.454235,
#      'lng': 30.521848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.454235,
#        'lng': 30.521848}],
#      'distance': 495,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Ул. Михайловская 22б', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '52e2415a498e5573763be6c5',
#     'name': 'Nota Bene school',
#     'location': {'address': 'вул. Володимирська, 7',
#      'lat': 50.45661926269531,
#      'lng': 30.518333435058594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.45661926269531,
#        'lng': 30.518333435058594}],
#      'distance': 840,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Володимирська, 7', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4f2c05a5e4b0a98a4913fa92',
#     'name': 'Green Forest (English School)',
#     'location': {'address': 'вул. Грушевського, 28/2',
#      'lat': 50.444694586266934,
#      'lng': 30.538756760635916,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.444694586266934,
#        'lng': 30.538756760635916}],
#      'distance': 1194,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Грушевського, 28/2', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4f5f05dbe4b080c3661c412c',
#     'name': 'Школа №49',
#     'location': {'address': 'вул. Ярославів Вал, 27',
#      'lat': 50.452853927853724,
#      'lng': 30.506971027975275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.452853927853724,
#        'lng': 30.506971027975275}],
#      'distance': 1256,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Ярославів Вал, 27', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4fd608c0e4b00127bae8e57d',
#     'name': 'Native English School',
#     'location': {'address': 'вул. Володимирська, 51/53, оф. 4',
#      'lat': 50.44629137061281,
#      'lng': 30.51347413991321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44629137061281,
#        'lng': 30.51347413991321}],
#      'distance': 862,
#      'postalCode': '01001',
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Володимирська, 51/53, оф. 4',
#       'Київ, 01001',
#       'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4f6055b0e4b00cb4e0308773',
#     'name': 'Школа №53',
#     'location': {'address': 'вул. Хмельницького, 16/18',
#      'lat': 50.446872571369084,
#      'lng': 30.51601510081148,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.446872571369084,
#        'lng': 30.51601510081148}],
#      'distance': 674,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Хмельницького, 16/18', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '57499138498ef19a1494d917',
#     'name': 'MoDo professional school',
#     'location': {'address': 'Zankovetskoi',
#      'lat': 50.44482,
#      'lng': 30.524551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44482,
#        'lng': 30.524551}],
#      'distance': 581,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Zankovetskoi', 'Київ', 'Україна']},
#     'categories': [{'id': '54541900498ea6ccd0202697',
#       'name': 'Health & Beauty Service',
#       'pluralName': 'Health & Beauty Services',
#       'shortName': 'Health & Beauty',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '509ceae4e4b0c4d83b265d5a',
#     'name': 'English" Holliday School"',
#     'location': {'lat': 50.44478013683614,
#      'lng': 30.525109990733256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44478013683614,
#        'lng': 30.525109990733256}],
#      'distance': 588,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d173941735',
#       'name': 'Auditorium',
#       'pluralName': 'Auditoriums',
#       'shortName': 'Auditorium',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/auditorium_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '56336993498e7eaaeefc7b30',
#     'name': 'Aesthetic Consilium School',
#     'location': {'address': 'Киев, ул. Оболонская набережная д.1',
#      'lat': 50.44274122496599,
#      'lng': 30.520584332817144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44274122496599,
#        'lng': 30.520584332817144}],
#      'distance': 849,
#      'postalCode': '04211',
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Киев, ул. Оболонская набережная д.1',
#       'Київ, 04211',
#       'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '55227aad498e186fc045dacd',
#     'name': 'kevin language school',
#     'location': {'lat': 50.4463030211627,
#      'lng': 30.5171495676041,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.4463030211627,
#        'lng': 30.5171495676041}],
#      'distance': 646,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '5641e067498e51f3a7c273c7',
#     'name': 'Hotspot School of English',
#     'location': {'address': 'Пушкинская, 9',
#      'lat': 50.44649905644397,
#      'lng': 30.518928704812453,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44649905644397,
#        'lng': 30.518928704812453}],
#      'distance': 539,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Пушкинская, 9', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '573c8b63498e6a4964df45c6',
#     'name': 'Tailors School',
#     'location': {'address': 'Ярославов Вал, 26Б',
#      'lat': 50.451990296717334,
#      'lng': 30.509429868524315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.451990296717334,
#        'lng': 30.509429868524315}],
#      'distance': 1064,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Ярославов Вал, 26Б', 'Київ', 'Україна']},
#     'categories': [{'id': '56aa371ce4b08b9a8d573570',
#       'name': 'Adult Education Center',
#       'pluralName': 'Adult Education Centers',
#       'shortName': 'Adult Education Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '55185852498ef09f78e9b14e',
#     'name': 'School of restaurant business MR.BAR',
#     'location': {'address': 'Харьков, Ул. Чернышевская 13, Офис 401',
#      'lat': 50.451424158064206,
#      'lng': 30.53367710902619,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.451424158064206,
#        'lng': 30.53367710902619}],
#      'distance': 693,
#      'cc': 'UA',
#      'city': 'Киев, ул. Грушевского 3',
#      'country': 'Україна',
#      'formattedAddress': ['Харьков, Ул. Чернышевская 13, Офис 401',
#       'Киев, ул. Грушевского 3',
#       'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4f97f944e4b07644b02f49eb',
#     'name': 'Nikland Business School',
#     'location': {'address': '1/2 Basseynaya',
#      'lat': 50.442771704622054,
#      'lng': 30.523227155400512,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.442771704622054,
#        'lng': 30.523227155400512}],
#      'distance': 810,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['1/2 Basseynaya', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '58cbd09245005e58340925ea',
#     'name': 'Higher School Of Communications',
#     'location': {'lat': 50.44632,
#      'lng': 30.515242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44632,
#        'lng': 30.515242}],
#      'distance': 753,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d1af941735',
#       'name': 'College Auditorium',
#       'pluralName': 'College Auditoriums',
#       'shortName': 'Auditorium',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/auditorium_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '53cf928f498e5507990b9b5e',
#     'name': 'City Business School',
#     'location': {'lat': 50.45668510017123,
#      'lng': 30.518489830935213,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.45668510017123,
#        'lng': 30.518489830935213}],
#      'distance': 841,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '5131bbbde4b02029e14e8547',
#     'name': 'Директ Мейл power school',
#     'location': {'lat': 50.447459,
#      'lng': 30.514772,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.447459,
#        'lng': 30.514772}],
#      'distance': 722,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d100941735',
#       'name': 'Meeting Room',
#       'pluralName': 'Meeting Rooms',
#       'shortName': 'Meeting Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/conventioncenter_meetingroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '51a4b593498ef97685dda05f',
#     'name': 'Native English School',
#     'location': {'address': 'Bessarabska, 7, 4 app.',
#      'lat': 50.44230521989427,
#      'lng': 30.522715117329863,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44230521989427,
#        'lng': 30.522715117329863}],
#      'distance': 866,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Bessarabska, 7, 4 app.', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4f76fc2ce4b05cde606251a5',
#     'name': 'Speak Well School',
#     'location': {'address': 'вул. Січових Стрільців, 1-5 оф. 701',
#      'crossStreet': 'пл. Львівська',
#      'lat': 50.455085955498596,
#      'lng': 30.505396127700802,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.455085955498596,
#        'lng': 30.505396127700802}],
#      'distance': 1442,
#      'postalCode': '04053',
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Січових Стрільців, 1-5 оф. 701 (пл. Львівська)',
#       'Київ, 04053',
#       'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '55f05c35498ed1c104f8a8de',
#     'name': 'Greenwich School',
#     'location': {'address': 'Хрещатик, 29, оф. 71',
#      'lat': 50.44296871719888,
#      'lng': 30.52178511427045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44296871719888,
#        'lng': 30.52178511427045}],
#      'distance': 803,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Хрещатик, 29, оф. 71', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4fb2b427a17c5518d70515c9',
#     'name': 'New York Language School',
#     'location': {'address': 'вул. Пилипа Орлика, 9',
#      'lat': 50.4429049527232,
#      'lng': 30.532582998275757,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.4429049527232,
#        'lng': 30.532582998275757}],
#      'distance': 994,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Пилипа Орлика, 9', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '52e923c511d228d0d5eb0178',
#     'name': 'Sky English School',
#     'location': {'lat': 50.441242420578355,
#      'lng': 30.520400383959245,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.441242420578355,
#        'lng': 30.520400383959245}],
#      'distance': 1013,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d1af941735',
#       'name': 'College Auditorium',
#       'pluralName': 'College Auditoriums',
#       'shortName': 'Auditorium',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/auditorium_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '50eec390e4b0ebd272aa5d0e',
#     'name': 'Drive vocal school',
#     'location': {'lat': 50.44664035008146,
#      'lng': 30.510898053804596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44664035008146,
#        'lng': 30.510898053804596}],
#      'distance': 1011,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4f04b10d2fb6e1c99f3db0be',
#       'name': 'Music School',
#       'pluralName': 'Music Schools',
#       'shortName': 'Music School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_music_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '55e8219b498e639db370f485',
#     'name': 'Can School',
#     'location': {'address': 'вул. Шовковична, 30б',
#      'lat': 50.4428596496582,
#      'lng': 30.52982521057129,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.4428596496582,
#        'lng': 30.52982521057129}],
#      'distance': 894,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Шовковична, 30б', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d199941735',
#       'name': 'College Arts Building',
#       'pluralName': 'College Arts Buildings',
#       'shortName': 'Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '54f4b381498e1e5f53517080',
#     'name': 'Advertising School',
#     'location': {'address': 'Рейтарская 21/13',
#      'lat': 50.45194484552404,
#      'lng': 30.510441740119965,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.45194484552404,
#        'lng': 30.510441740119965}],
#      'distance': 993,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Рейтарская 21/13', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a32',
#       'name': 'Cultural Center',
#       'pluralName': 'Cultural Centers',
#       'shortName': 'Cultural Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4e8061e37beb547f5099f628',
#     'name': 'Comman Business School',
#     'location': {'address': 'Darvina 10',
#      'lat': 50.44070479627428,
#      'lng': 30.525931119918823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44070479627428,
#        'lng': 30.525931119918823}],
#      'distance': 1046,
#      'postalCode': '01004',
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Darvina 10', 'Київ, 01004', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '4fd20f37e4b0d64ed84391e9',
#     'name': 'Design School',
#     'location': {'lat': 50.44899630503608,
#      'lng': 30.509119505947233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44899630503608,
#        'lng': 30.509119505947233}],
#      'distance': 1070,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '5554c305498ebcc5f4a8e071',
#     'name': 'Free Art School',
#     'location': {'address': 'вул. Рейтарська, 7',
#      'lat': 50.451729965017904,
#      'lng': 30.512033721067397,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.451729965017904,
#        'lng': 30.512033721067397}],
#      'distance': 878,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Рейтарська, 7', 'Київ', 'Україна']},
#     'categories': [{'id': '4f04b10d2fb6e1c99f3db0be',
#       'name': 'Music School',
#       'pluralName': 'Music Schools',
#       'shortName': 'Music School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_music_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '516d2a55e4b0dfc7763b708d',
#     'name': 'Nota bene school',
#     'location': {'address': 'Volodimirska 7',
#      'lat': 50.458685,
#      'lng': 30.515093,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.458685,
#        'lng': 30.515093}],
#      'distance': 1156,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['Volodimirska 7', 'Київ', 'Україна']},
#     'categories': [{'id': '4bf58dd8d48988d173941735',
#       'name': 'Auditorium',
#       'pluralName': 'Auditoriums',
#       'shortName': 'Auditorium',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/auditorium_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '51d2ed38498eb65ee4e742ab',
#     'name': 'Green Forest',
#     'location': {'address': 'вул. Басейна, 7В',
#      'lat': 50.44100871008197,
#      'lng': 30.523544766348913,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.44100871008197,
#        'lng': 30.523544766348913}],
#      'distance': 1005,
#      'cc': 'UA',
#      'city': 'Київ',
#      'state': 'м. Київ',
#      'country': 'Україна',
#      'formattedAddress': ['вул. Басейна, 7В', 'Київ', 'Україна']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False},
#    {'id': '51287f34e4b03513fef8406d',
#     'name': 'Fashion School',
#     'location': {'lat': 50.447191736426824,
#      'lng': 30.508887873442482,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.447191736426824,
#        'lng': 30.508887873442482}],
#      'distance': 1126,
#      'cc': 'UA',
#      'country': 'Україна',
#      'formattedAddress': ['Україна']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1566813304',
#     'hasPerk': False}]}}

# %%
#declaring same function we used to collect venuse data and store them (I've commented printing each name)
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
#Getting information of not more than 100 venues for each neighborhood
LIMIT = 200
city_venues = getNearbyVenues(names=results['Name'],
                                   latitudes=results['Latitude'],
                                   longitudes=results['Longitude']
                                  )

# %%
city_venues
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0          Kyiv              50.450034               30.524136
# 1          Kyiv              50.450034               30.524136
# 2          Kyiv              50.450034               30.524136
# 3          Kyiv              50.450034               30.524136
# 4          Kyiv              50.450034               30.524136
# 5          Kyiv              50.450034               30.524136
# 6          Kyiv              50.450034               30.524136
# 7          Kyiv              50.450034               30.524136
# 8          Kyiv              50.450034               30.524136
# 9          Kyiv              50.450034               30.524136
# 10         Kyiv              50.450034               30.524136
# 11         Kyiv              50.450034               30.524136
# 12         Kyiv              50.450034               30.524136
# 13         Kyiv              50.450034               30.524136
# 14         Kyiv              50.450034               30.524136
# 15         Kyiv              50.450034               30.524136
# 16         Kyiv              50.450034               30.524136
# 17         Kyiv              50.450034               30.524136
# 18         Kyiv              50.450034               30.524136
# 19         Kyiv              50.450034               30.524136
# 20         Kyiv              50.450034               30.524136
# 21         Kyiv              50.450034               30.524136
# 22         Kyiv              50.450034               30.524136
# 23         Kyiv              50.450034               30.524136
# 24         Kyiv              50.450034               30.524136
# 25         Kyiv              50.450034               30.524136
# 26         Kyiv              50.450034               30.524136
# 27         Kyiv              50.450034               30.524136
# 28         Kyiv              50.450034               30.524136
# 29         Kyiv              50.450034               30.524136
# 30         Kyiv              50.450034               30.524136
# 31         Kyiv              50.450034               30.524136
# 32         Kyiv              50.450034               30.524136
# 33         Kyiv              50.450034               30.524136
# 34         Kyiv              50.450034               30.524136
# 35         Kyiv              50.450034               30.524136
# 36         Kyiv              50.450034               30.524136
# 37         Kyiv              50.450034               30.524136
# 38         Kyiv              50.450034               30.524136
# 39         Kyiv              50.450034               30.524136
# 40         Kyiv              50.450034               30.524136
# 41         Kyiv              50.450034               30.524136
# 42         Kyiv              50.450034               30.524136
# 43         Kyiv              50.450034               30.524136
# 44         Kyiv              50.450034               30.524136
# 45         Kyiv              50.450034               30.524136
# 46         Kyiv              50.450034               30.524136
# 47         Kyiv              50.450034               30.524136
# 48         Kyiv              50.450034               30.524136
# 49         Kyiv              50.450034               30.524136
# 50         Kyiv              50.450034               30.524136
# 51         Kyiv              50.450034               30.524136
# 52         Kyiv              50.450034               30.524136
# 53         Kyiv              50.450034               30.524136
# 54         Kyiv              50.450034               30.524136
# 55         Kyiv              50.450034               30.524136
# 56         Kyiv              50.450034               30.524136
# 57         Kyiv              50.450034               30.524136
# 58         Kyiv              50.450034               30.524136
# 59         Kyiv              50.450034               30.524136
# 60         Kyiv              50.450034               30.524136
# 61         Kyiv              50.450034               30.524136
# 62         Kyiv              50.450034               30.524136
# 63         Kyiv              50.450034               30.524136
# 64         Kyiv              50.450034               30.524136
# 65         Kyiv              50.450034               30.524136
# 66         Kyiv              50.450034               30.524136
# 67         Kyiv              50.450034               30.524136
# 68         Kyiv              50.450034               30.524136
# 69         Kyiv              50.450034               30.524136
# 70         Kyiv              50.450034               30.524136
# 71         Kyiv              50.450034               30.524136
# 72         Kyiv              50.450034               30.524136
# 73         Kyiv              50.450034               30.524136
# 74         Kyiv              50.450034               30.524136
# 75         Kyiv              50.450034               30.524136
# 76         Kyiv              50.450034               30.524136
# 77         Kyiv              50.450034               30.524136
# 78         Kyiv              50.450034               30.524136
# 79         Kyiv              50.450034               30.524136
# 80         Kyiv              50.450034               30.524136
# 81         Kyiv              50.450034               30.524136
# 82         Kyiv              50.450034               30.524136
# 83         Kyiv              50.450034               30.524136
# 84         Kyiv              50.450034               30.524136
# 85         Kyiv              50.450034               30.524136
# 86         Kyiv              50.450034               30.524136
# 87         Kyiv              50.450034               30.524136
# 88         Kyiv              50.450034               30.524136
# 89         Kyiv              50.450034               30.524136
# 90         Kyiv              50.450034               30.524136
# 91         Kyiv              50.450034               30.524136
# 92         Kyiv              50.450034               30.524136
# 93         Kyiv              50.450034               30.524136
# 94         Kyiv              50.450034               30.524136
# 95         Kyiv              50.450034               30.524136
# 96         Kyiv              50.450034               30.524136
# 97         Kyiv              50.450034               30.524136
# 98         Kyiv              50.450034               30.524136
# 99         Kyiv              50.450034               30.524136
#
#                                                 Venue  Venue Latitude  \
# 0                                            Cinnabon       50.450865
# 1                                         П‘яна Вишня       50.450969
# 2                                       Très Français       50.451462
# 3                                          Art Eclair       50.451980
# 4                                 Майдан Незалежності       50.449939
# 5                                             UA made       50.450635
# 6                                           МАМА ГОЧІ       50.448205
# 7                                  Львівські Круасани       50.449121
# 8                                                Умка       50.452139
# 9                                   Soroka Coffee Bar       50.448299
# 10                                          Lenny Bus       50.447853
# 11                                         Пивна Дума       50.451756
# 12                                   Остання Барикада       50.450962
# 13                                     Very Well Café       50.447817
# 14                                      Louis Vuitton       50.447863
# 15                Оглядовий майданчик над ТЦ «Глобус»       50.449312
# 16                                         Pesto Cafe       50.449273
# 17                                        Cuba Coffee       50.450968
# 18                                            Rozetka       50.450042
# 19                                   Закохані ліхтарі       50.451203
# 20                                          Salateira       50.450948
# 21                                  Фонтан на Майдані       50.450837
# 22                                         Nike Store       50.451456
# 23                                      Файна Фамілія       50.451767
# 24                               Showroom Квартира 31       50.452207
# 25                                        П'яна Вишня       50.448203
# 26                                           folkmart       50.448890
# 27                         Turkish House Grill Lounge       50.448786
# 28                                    Urban Space 500       50.448938
# 29                                         Buddha Bar       50.451665
# 30                             One Little Coffee Shop       50.451663
# 31                                           TEAHOUSE       50.451499
# 32                                              Pache       50.451700
# 33                                             Miniso       50.448103
# 34                                        Star Burger       50.451270
# 35                                           Mamamia!       50.452083
# 36                                        Madame Josy       50.450398
# 37                                 Yves Saint Laurent       50.447534
# 38                                              Каффа       50.450647
# 39                         VIDRO Craft Beer & Kitchen       50.450899
# 40                           Kiev Yoga Studio (Bodhi)       50.453088
# 41                                         UiPservice       50.452927
# 42                                    Пасаж / Passage       50.447845
# 43                                   Balagan Vape Bar       50.447551
# 44                Ресторан QIRIM / Крим / Крым (Крим)       50.450871
# 45                                       ЦОА Київстар       50.448824
# 46                          Senator Apartments Maidan       50.451012
# 47                                          Mr. Grill       50.451050
# 48                                         Smørrebrød       50.448940
# 49                                 N::B Cocktails Bar       50.453176
# 50                             Всі. Свої Дім та декор       50.446758
# 51                                      PHILIPP PLEIN       50.447080
# 52                                             Mojito       50.448402
# 53                                          Coffeelat       50.450997
# 54                          Бутик "No Taboo" Крещатик       50.447603
# 55                                             NebO's       50.451834
# 56                              TIU Kreschatik Hostel       50.452235
# 57                                           Pistrina       50.453499
# 58                                     Pizza Veterano       50.451893
# 59                                           SANPAOLO       50.449768
# 60                                           Tom Sour       50.451570
# 61                                    11 Silver Space       50.452689
# 62                     Національна філармонія України       50.453122
# 63                                      Panorama Club       50.451541
# 64                                                NYX       50.450977
# 65                                       Make My Cake       50.446246
# 66                                 Театр "Дивнi Люди"       50.449249
# 67                                             McCafé       50.447298
# 68                                   DRUZI cafe & bar       50.447520
# 69                                  На Станиславского       50.446300
# 70                                            Georgia       50.452140
# 71                                              Mocco       50.447583
# 72                                 Sereda Vegan Point       50.448505
# 73  Церква святого Олександра / St. Alexander's Ch...       50.453011
# 74                                            Artarea       50.451764
# 75                       Львівська майстерня шоколаду       50.446984
# 76                                   Бар твоих друзей       50.453223
# 77                     Книгарня-кав’ярня Старого Лева       50.448484
# 78                                      RockFellow210       50.453062
# 79                                       The Blue Cup       50.447374
# 80                                  Європейська площа       50.452262
# 81                                          Дрінкарня       50.453640
# 82                                          Le Komora       50.447807
# 83                                          Чачаварня       50.447960
# 84                                 Французская аптека       50.446234
# 85                                Моя книжкова полиця       50.447050
# 86  Киевский академический театр кукол (Київський ...       50.451929
# 87                                 Сквер на Прорізній       50.448128
# 88                                 Площа Івана Франка       50.446104
# 89                                               DIOR       50.446427
# 90                                  Coffee Laboratory       50.453942
# 91                                      BalLet Hostel       50.451240
# 92                                        Команда ЭКС       50.453382
# 93                                  Meeting Place OVD       50.451402
# 94                                   KU•KU coffee&eat       50.453546
# 95                                              Trava       50.453092
# 96  Національний художній музей України / National...       50.449348
# 97                                     Prime Body Art       50.449323
# 98                                      Menya Musashi       50.446731
# 99                         The Wings Leather Workshop       50.453499
#
#     Venue Longitude                 Venue Category
# 0         30.522829                         Bakery
# 1         30.521464                   Cocktail Bar
# 2         30.523311              French Restaurant
# 3         30.523797                   Dessert Shop
# 4         30.524118                          Plaza
# 5         30.523261                      Gift Shop
# 6         30.525640           Caucasian Restaurant
# 7         30.522810                         Bakery
# 8         30.524015                 Ice Cream Shop
# 9         30.522869                    Coffee Shop
# 10        30.525974                    Coffee Shop
# 11        30.525947                        Brewery
# 12        30.522758           Ukrainian Restaurant
# 13        30.525743                           Café
# 14        30.524579                       Boutique
# 15        30.526005                 Scenic Lookout
# 16        30.525921             Italian Restaurant
# 17        30.521181                    Coffee Shop
# 18        30.522707              Electronics Store
# 19        30.522186                     Street Art
# 20        30.522735                    Salad Place
# 21        30.522873                       Fountain
# 22        30.527072            Sporting Goods Shop
# 23        30.521815       Mediterranean Restaurant
# 24        30.524041                       Boutique
# 25        30.522830                       Wine Bar
# 26        30.523119                  Souvenir Shop
# 27        30.522468             Turkish Restaurant
# 28        30.520384     Modern European Restaurant
# 29        30.524965               Asian Restaurant
# 30        30.520424                    Coffee Shop
# 31        30.521087                    Coffee Shop
# 32        30.523360                     Steakhouse
# 33        30.523006                      Gift Shop
# 34        30.525912                   Burger Joint
# 35        30.521465                    Pizza Place
# 36        30.521365                   Dessert Shop
# 37        30.526203                       Boutique
# 38        30.520730                    Coffee Shop
# 39        30.521329                       Beer Bar
# 40        30.522561                    Yoga Studio
# 41        30.522024              Electronics Store
# 42        30.524075               Pedestrian Plaza
# 43        30.521130                   Cocktail Bar
# 44        30.521661               Tatar Restaurant
# 45        30.522997              Mobile Phone Shop
# 46        30.519927                          Hotel
# 47        30.525528                  Hot Dog Joint
# 48        30.524045        Scandinavian Restaurant
# 49        30.521881                   Cocktail Bar
# 50        30.521853                      Gift Shop
# 51        30.525697                       Boutique
# 52        30.523247                   Cocktail Bar
# 53        30.522676                    Coffee Shop
# 54        30.522737                 Adult Boutique
# 55        30.521223  Vegetarian / Vegan Restaurant
# 56        30.525547                         Hostel
# 57        30.525329                         Bakery
# 58        30.520018                    Pizza Place
# 59        30.529531           Brazilian Restaurant
# 60        30.520760                            Bar
# 61        30.520207                  Jewelry Store
# 62        30.527726                   Concert Hall
# 63        30.527286                     Restaurant
# 64        30.522700                 Cosmetics Shop
# 65        30.526435                   Dessert Shop
# 66        30.520695                        Theater
# 67        30.522930                    Coffee Shop
# 68        30.520360                           Café
# 69        30.526470                    Coffee Shop
# 70        30.526459           Caucasian Restaurant
# 71        30.525136           Ukrainian Restaurant
# 72        30.519292                   Dessert Shop
# 73        30.525248                         Church
# 74        30.518987                         Museum
# 75        30.522229                 Chocolate Shop
# 76        30.521645                            Bar
# 77        30.518377                    Coffee Shop
# 78        30.519112            Indie Movie Theater
# 79        30.519047                    Coffee Shop
# 80        30.527776                          Plaza
# 81        30.521511                       Dive Bar
# 82        30.518729               Swiss Restaurant
# 83        30.519557                     Restaurant
# 84        30.522803                       Pharmacy
# 85        30.518934                      Bookstore
# 86        30.530163                        Theater
# 87        30.519505                           Park
# 88        30.527412                          Plaza
# 89        30.525057                       Boutique
# 90        30.521268                           Café
# 91        30.518713                         Hostel
# 92        30.521806            Sporting Goods Shop
# 93        30.518343                    Coffee Shop
# 94        30.521942                    Coffee Shop
# 95        30.519088                   Cocktail Bar
# 96        30.530770                     Art Museum
# 97        30.517660                Piercing Parlor
# 98        30.522978               Ramen Restaurant
# 99        30.519785            Leather Goods Store
